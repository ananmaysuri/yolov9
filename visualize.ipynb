# %%
# !git clone https://github.com/WongKinYiu/yolov9.git
# Out:
# Cloning into 'yolov9'...
# remote: Enumerating objects: 668, done.
# remote: Counting objects: 100% (290/290), done.
# remote: Compressing objects: 100% (91/91), done.
# remote: Total 668 (delta 222), reused 199 (delta 199), pack-reused 378
# Receiving objects: 100% (668/668), 3.22 MiB | 25.79 MiB/s, done.
# Resolving deltas: 100% (269/269), done.

# %%
# !pip3 install -r yolov9/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 19.3 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...

# %%
# !unzip deep_fashion_dataset.zip
# Out:
# Archive:  deep_fashion_dataset.zip
#    creating: deep_fashion_dataset/
#   inflating: deep_fashion_dataset/.DS_Store
#   inflating: __MACOSX/deep_fashion_dataset/._.DS_Store
#    creating: deep_fashion_dataset/test/
#    creating: deep_fashion_dataset/train/
#   inflating: deep_fashion_dataset/dataset.yaml
#   inflating: __MACOSX/deep_fashion_dataset/._dataset.yaml
#    creating: deep_fashion_dataset/val/
#   inflating: deep_fashion_dataset/test/.DS_Store
#   inflating: __MACOSX/deep_fashion_dataset/test/._.DS_Store
#    creating: deep_fashion_dataset/test/images/
#    creating: deep_fashion_dataset/test/labels/
#   inflating: deep_fashion_dataset/train/.DS_Store
#   inflating: __MACOSX/deep_fashion_dataset/train/._.DS_Store
#    creating: deep_fashion_dataset/train/images/
#    creating: deep_fashion_dataset/train/labels/
#   inflating: deep_fashion_dataset/val/.DS_Store
#   inflating: __MACOSX/deep_fashion_dataset/val/._.DS_Store
#    creating: deep_fashion_dataset/val/images/
# ...

# %%
# !python yolov9/segment/train.py --config yolov9/config.yaml
# Out:
# 2024-05-08 01:30:31.342404: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-08 01:30:31.342457: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-08 01:30:31.343823: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-08 01:30:32.379637: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
# !zip -r runs.zip runs
# Out:
#   adding: runs/ (stored 0%)
#   adding: runs/train-seg/ (stored 0%)
#   adding: runs/train-seg/custom-gelan-c-seg.yaml/ (stored 0%)
#   adding: runs/train-seg/custom-gelan-c-seg.yaml/weights/ (stored 0%)
#   adding: runs/train-seg/custom-gelan-c-seg.yaml/weights/last.pt (deflated 8%)
#   adding: runs/train-seg/custom-gelan-c-seg.yaml/weights/best.pt (deflated 8%)
#   adding: runs/train-seg/custom-gelan-c-seg.yaml/events.out.tfevents.1715131833.995cadd43f19.1122.0 (deflated 76%)
#   adding: runs/train-seg/custom-gelan-c-seg.yaml/results.csv (deflated 94%)
#   adding: runs/train-seg/custom-gelan-c-seg.yaml/hyp.yaml (deflated 43%)
#   adding: runs/train-seg/custom-gelan-c-seg.yaml/opt.yaml (deflated 50%)

# %%
# !unzip yolov9/runs
# Out:
# Archive:  yolov9/runs.zip
#    creating: runs/
#   inflating: __MACOSX/._runs
#    creating: runs/train-seg/
#   inflating: __MACOSX/runs/._train-seg
#    creating: runs/train-seg/custom-gelan-c-seg.yaml/
#   inflating: __MACOSX/runs/train-seg/._custom-gelan-c-seg.yaml
#   inflating: runs/train-seg/custom-gelan-c-seg.yaml/events.out.tfevents.1715131833.995cadd43f19.1122.0
#   inflating: __MACOSX/runs/train-seg/custom-gelan-c-seg.yaml/._events.out.tfevents.1715131833.995cadd43f19.1122.0
#    creating: runs/train-seg/custom-gelan-c-seg.yaml/weights/
#   inflating: __MACOSX/runs/train-seg/custom-gelan-c-seg.yaml/._weights
#   inflating: runs/train-seg/custom-gelan-c-seg.yaml/hyp.yaml
#   inflating: __MACOSX/runs/train-seg/custom-gelan-c-seg.yaml/._hyp.yaml
#   inflating: runs/train-seg/custom-gelan-c-seg.yaml/opt.yaml
#   inflating: __MACOSX/runs/train-seg/custom-gelan-c-seg.yaml/._opt.yaml
#   inflating: runs/train-seg/custom-gelan-c-seg.yaml/results.csv
# ...

# %%
# !python3 yolov9/segment/val.py --weights runs/train-seg/custom-gelan-c-seg.yaml/weights/best.pt --data deep_fashion_dataset/dataset.yaml
# Out:
# segment/val: data=deep_fashion_dataset/dataset.yaml, weights=['runs/train-seg/custom-gelan-c-seg.yaml/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=yolov9/runs/val-seg, name=exp, exist_ok=False, half=False, dnn=False
# YOLO 🚀 v0.1-89-g93f1a28 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# gelan-c-seg summary: 414 layers, 27364441 parameters, 0 gradients, 144.2 GFLOPs
# ...
# 100% 755k/755k [00:00<00:00, 44.3MB/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# ...

# %%
# !zip -r val-seg.zip /content/yolov9/runs/val-seg
# Out:
#   adding: content/yolov9/runs/val-seg/ (stored 0%)
#   adding: content/yolov9/runs/val-seg/exp/ (stored 0%)
#   adding: content/yolov9/runs/val-seg/exp/BoxF1_curve.png (deflated 17%)
#   adding: content/yolov9/runs/val-seg/exp/val_batch0_pred.jpg (deflated 13%)
#   adding: content/yolov9/runs/val-seg/exp/MaskR_curve.png (deflated 17%)
#   adding: content/yolov9/runs/val-seg/exp/BoxPR_curve.png (deflated 19%)
#   adding: content/yolov9/runs/val-seg/exp/BoxP_curve.png (deflated 12%)
#   adding: content/yolov9/runs/val-seg/exp/confusion_matrix.png (deflated 28%)
#   adding: content/yolov9/runs/val-seg/exp/MaskF1_curve.png (deflated 17%)
#   adding: content/yolov9/runs/val-seg/exp/BoxR_curve.png (deflated 20%)
#   adding: content/yolov9/runs/val-seg/exp/val_batch0_labels.jpg (deflated 14%)
#   adding: content/yolov9/runs/val-seg/exp/MaskPR_curve.png (deflated 20%)
#   adding: content/yolov9/runs/val-seg/exp/MaskP_curve.png (deflated 12%)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from pathlib import Path

image_dir = '/content/yolov9/runs/val-seg/exp/'

image_files = [
    "BoxF1_curve.png", "BoxP_curve.png", "BoxPR_curve.png", "BoxR_curve.png",
    "confusion_matrix.png", "MaskF1_curve.png", "MaskP_curve.png",
    "MaskPR_curve.png", "MaskR_curve.png"]

fig, axs = plt.subplots(nrows=len(image_files), figsize=(10, 5 * len(image_files)))

for ax, img_name in zip(axs, image_files):
    img_path = image_dir + img_name
    img = mpimg.imread(img_path)
    ax.imshow(img)
    ax.title.set_text(img_name)
    ax.axis('off')

plt.show()

# %%
image_files = ["val_batch0_labels.jpg", "val_batch0_pred.jpg"]

fig, axs = plt.subplots(nrows=len(image_files), figsize=(20, 15))

for ax, img_name in zip(axs, image_files):
    img_path = image_dir + img_name
    img = mpimg.imread(img_path)
    ax.imshow(img)
    ax.title.set_text(img_name)
    ax.axis('off')

plt.tight_layout()
plt.show()
